# %% [markdown]
# # Lab 3: Bayes Classifier and Boosting

# %% [markdown]
# ## Jupyter notebooks
#
# In this lab, you can use Jupyter <https://jupyter.org/> to get a nice layout of your code and plots in one document. However, you may also use Python as usual, without Jupyter.
#
# If you have Python and pip, you can install Jupyter with `sudo pip install jupyter`. Otherwise you can follow the instruction on <http://jupyter.readthedocs.org/en/latest/install.html>.
#
# And that is everything you need! Now use a terminal to go into the folder with the provided lab files. Then run `jupyter notebook` to start a session in that folder. Click `lab3.ipynb` in the browser window that appeared to start this very notebook. You should click on the cells in order and either press `ctrl+enter` or `run cell` in the toolbar above to evaluate all the expressions.
#
# Be sure to put `%matplotlib inline` at the top of every code cell where you call plotting functions to get the resulting plots inside the document.

# %% [markdown]
# ## Import the libraries
#
# In Jupyter, select the cell below and press `ctrl + enter` to import the needed libraries.
# Check out `labfuns.py` if you are interested in the details.

# %%
import numpy as np
from scipy import misc
from imp import reload
from labfuns import *
import random
from helpers import *
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Assignment 1 & 4
# Write the function `mlParams(x, labels)` for assignment 1 and then extend it to `mlParams(x, labels, W)` for assignment 4.

# %% [markdown]
# ## Assignment 2
# Write the following functions:
# * `computePrior(labels)` estimates and returns the class prior in X (ignore the `W` argument)
# * `classifyBayes(X, prior, mu, sigma)` computes the discriminant function values for all classes and data points, and classifies each point to belong to the max discriminant value.

# %% [markdown]
# The implemented functions can now be summarized into the `BayesClassifier` class, which we will use later to test the classifier.

# %%
# NOTE: no need to touch this
from helpers import *

class BayesClassifier(object):
    def __init__(self):
        self.trained = False

    def trainClassifier(self, X, labels, W=None):
        rtn = BayesClassifier()
        rtn.prior = computePrior(labels, W)
        rtn.mu, rtn.sigma = mlParams(X, labels, W)
        rtn.trained = True
        return rtn

    def classify(self, X):
        return classifyBayes(X, self.prior, self.mu, self.sigma)

# %% [markdown]
# ## Assignment 3
#
# We now have all the functions we need for doing the training and classification. Use the provided `testClassifier` to test the accuracy of the `vowels` and `iris` datasets. Tasks:
# 1. Use the provided random partitioning function to split the dataset into a training and test dataset.
# 2. Train your classifier on the training partition.
# 3. Evaluate the performance of the classifier on the test partition.
#
# ### Questions
#
# **When can a feature independence assumption be reasonable and when not?**
#
# Bayes classifiers treat features as if they were independent. For example, when the input is two words, say "Dear" and "Friend", the output of "Dear Friend" and "Friend Dear" is the same (this is why it's called naive). While this is not how our languages work, surprisingly these models work pretty well despite the conditional independence assumption. Despite the fact that sepal length and sepal width, as well as petal length and petal width should be closely correlated in reality, the classifier does just fine.
#
# **How does the decision boundary look for the Iris dataset? How could one improve
# the classification results for this scenario by changing classifier or, alternatively,
# manipulating the data?**
#
# We get a good decision boundary between classes 0 and 1. However, the decision boundary for classes 1 and 2 is less precise and some records are incorrectly classfied. This is because of the weak nature of the classifier. We think a support vector machine or random forest could have been a better classifier, perhaps with a high slack or complex kernel.

# %% [markdown]
# Call the `testClassifier` and `plotBoundary` functions for this part.

# %%
testClassifier(BayesClassifier(), dataset='iris', split=0.7)
# Out:
# Trial: 0 Accuracy 84.4
# Trial: 10 Accuracy 97.8
# Trial: 20 Accuracy 91.1
# Trial: 30 Accuracy 86.7
# Trial: 40 Accuracy 88.9
# Trial: 50 Accuracy 91.1
# Trial: 60 Accuracy 86.7
# Trial: 70 Accuracy 91.1
# Trial: 80 Accuracy 86.7
# Trial: 90 Accuracy 91.1
# Final mean classification accuracy  89.2 with standard deviation 4.19

# %%
# %matplotlib inline
plotBoundary(BayesClassifier(), dataset='iris',split=0.7)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
testClassifier(BayesClassifier(), dataset='vowel', split=0.7)
# Out:
# Trial: 0 Accuracy 52.6
# Trial: 10 Accuracy 61.7
# Trial: 20 Accuracy 68.2
# Trial: 30 Accuracy 62.3
# Trial: 40 Accuracy 56.5
# Trial: 50 Accuracy 63
# Trial: 60 Accuracy 64.3
# Trial: 70 Accuracy 62.3
# Trial: 80 Accuracy 60.4
# Trial: 90 Accuracy 65.6
# Final mean classification accuracy  61.3 with standard deviation 3.48

# %%
# %matplotlib inline
plotBoundary(BayesClassifier(), dataset='vowel',split=0.7)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ## Assignment 4 (Boosting)
#
# The lab descriptions state what each function should do.

# %% [markdown]
# The implemented functions can now be summarized another classifer, the `BoostClassifier` class. This class enables boosting different types of classifiers by initializing it with the `base_classifier` argument. No need to add anything here.

# %%
from helpers import *

# NOTE: no need to touch this
class BoostClassifier(object):
    def __init__(self, base_classifier, T=10):
        self.base_classifier = base_classifier
        self.T = T
        self.trained = False

    def trainClassifier(self, X, labels):
        rtn = BoostClassifier(self.base_classifier, self.T)
        rtn.nbr_classes = np.size(np.unique(labels))
        rtn.classifiers, rtn.alphas = trainBoost(self.base_classifier, X, labels, self.T)
        rtn.trained = True
        return rtn

    def classify(self, X):
        return classifyBoost(X, self.classifiers, self.alphas, self.nbr_classes)

# %% [markdown]
# ## Run some experiments
#
# Call the `testClassifier` and `plotBoundary` functions for this part.

# %% [markdown]
# ### Iris Dataset

# %%
# Standard Bayes Classifier
testClassifier(BayesClassifier(), dataset='iris', split=0.7)
# %matplotlib inline
plotBoundary(BayesClassifier(), dataset='iris',split=0.7)
# Out:
# Trial: 0 Accuracy 84.4
# Trial: 10 Accuracy 97.8
# Trial: 20 Accuracy 91.1
# Trial: 30 Accuracy 86.7
# Trial: 40 Accuracy 88.9
# Trial: 50 Accuracy 91.1
# Trial: 60 Accuracy 86.7
# Trial: 70 Accuracy 91.1
# Trial: 80 Accuracy 86.7
# Trial: 90 Accuracy 91.1
# Final mean classification accuracy  89.2 with standard deviation 4.19
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
# Boosted Bayes Classifier
testClassifier(BoostClassifier(BayesClassifier(), T=10), dataset='iris',split=0.7)
# %matplotlib inline
plotBoundary(BoostClassifier(BayesClassifier()), dataset='iris',split=0.7)
# Out:
# Trial: 0 Accuracy 100
# /Users/cesaredecal/Documents/GitHub/DD2421-ML-Labs/lab_3/helpers.py:139: RuntimeWarning: invalid value encountered in log
#   curAlpha = (np.log(1 - error) - np.log(error))/2 # Compute new alpha
# /opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:2116: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# Trial: 10 Accuracy 97.8
# Trial: 20 Accuracy 93.3
# Trial: 30 Accuracy 93.3
# Trial: 40 Accuracy 97.8
# Trial: 50 Accuracy 86.7
# Trial: 60 Accuracy 93.3
# Trial: 70 Accuracy 95.6
# Trial: 80 Accuracy 93.3
# Trial: 90 Accuracy 95.6
# Final mean classification accuracy  94.2 with standard deviation 6.83
# ...

# %%
testClassifier(DecisionTreeClassifier(), dataset='iris',split=0.7)
# %matplotlib inline
plotBoundary(DecisionTreeClassifier(), dataset='iris',split=0.7)
# Out:
# Trial: 0 Accuracy 95.6
# Trial: 10 Accuracy 100
# Trial: 20 Accuracy 91.1
# Trial: 30 Accuracy 91.1
# Trial: 40 Accuracy 93.3
# Trial: 50 Accuracy 91.1
# Trial: 60 Accuracy 88.9
# Trial: 70 Accuracy 88.9
# Trial: 80 Accuracy 93.3
# Trial: 90 Accuracy 88.9
# Final mean classification accuracy  92.4 with standard deviation 3.71
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
testClassifier(BoostClassifier(DecisionTreeClassifier(), T=10), dataset='iris',split=0.7)
# %matplotlib inline
plotBoundary(BoostClassifier(DecisionTreeClassifier(), T=10), dataset='iris',split=0.7)
# Out:
# Trial: 0 Accuracy 95.6
# Trial: 10 Accuracy 100
# Trial: 20 Accuracy 95.6
# Trial: 30 Accuracy 91.1
# Trial: 40 Accuracy 93.3
# Trial: 50 Accuracy 95.6
# Trial: 60 Accuracy 88.9
# Trial: 70 Accuracy 93.3
# Trial: 80 Accuracy 93.3
# Trial: 90 Accuracy 93.3
# Final mean classification accuracy  94.6 with standard deviation 3.67
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### Vowel dataset

# %%
# Standard Naive Bayes Classifier
testClassifier(BayesClassifier(), dataset='vowel', split=0.7)
# %matplotlib inline
plotBoundary(BayesClassifier(), dataset='vowel',split=0.7)
# Out:
# Trial: 0 Accuracy 52.6
# Trial: 10 Accuracy 61.7
# Trial: 20 Accuracy 68.2
# Trial: 30 Accuracy 62.3
# Trial: 40 Accuracy 56.5
# Trial: 50 Accuracy 63
# Trial: 60 Accuracy 64.3
# Trial: 70 Accuracy 62.3
# Trial: 80 Accuracy 60.4
# Trial: 90 Accuracy 65.6
# Final mean classification accuracy  61.3 with standard deviation 3.48
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
# Boosted Naive Bayes Classifier
testClassifier(BoostClassifier(BayesClassifier(), T=10), dataset='vowel',split=0.7)
# %matplotlib inline
plotBoundary(BoostClassifier(BayesClassifier()), dataset='vowel',split=0.7)
# Out:
# Trial: 0 Accuracy 68.8
# Trial: 10 Accuracy 77.9
# Trial: 20 Accuracy 77.3
# Trial: 30 Accuracy 70.1
# Trial: 40 Accuracy 68.8
# Trial: 50 Accuracy 68.2
# Trial: 60 Accuracy 77.3
# Trial: 70 Accuracy 70.8
# Trial: 80 Accuracy 71.4
# Trial: 90 Accuracy 82.5
# Final mean classification accuracy  74.1 with standard deviation 3.73
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# Now repeat the steps with a decision tree classifier.

# %%
testClassifier(DecisionTreeClassifier(), dataset='vowel',split=0.7)
# %matplotlib inline
plotBoundary(DecisionTreeClassifier(), dataset='vowel',split=0.7)
# Out:
# Trial: 0 Accuracy 63.6
# Trial: 10 Accuracy 68.8
# Trial: 20 Accuracy 63.6
# Trial: 30 Accuracy 66.9
# Trial: 40 Accuracy 59.7
# Trial: 50 Accuracy 63
# Trial: 60 Accuracy 59.7
# Trial: 70 Accuracy 68.8
# Trial: 80 Accuracy 59.7
# Trial: 90 Accuracy 68.2
# Final mean classification accuracy  64.1 with standard deviation 4
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %%
testClassifier(BoostClassifier(DecisionTreeClassifier(), T=10), dataset='vowel',split=0.7)
# %matplotlib inline
plotBoundary(BoostClassifier(DecisionTreeClassifier(), T=10), dataset='vowel',split=0.7)
# Out:
# Trial: 0 Accuracy 86.4
# Trial: 10 Accuracy 87.7
# Trial: 20 Accuracy 87
# Trial: 30 Accuracy 92.2
# Trial: 40 Accuracy 83.8
# Trial: 50 Accuracy 81.2
# Trial: 60 Accuracy 90.3
# Trial: 70 Accuracy 89.6
# Trial: 80 Accuracy 86.4
# Trial: 90 Accuracy 86.4
# Final mean classification accuracy  86.5 with standard deviation 2.85
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# ### Questions
# **Is there any improvement in classification accuracy? Why/why not?**
#
# Yes, the boosted classifiers perform better.
#
# For the iris dataset:
# - **5% increase** in accuracy for the naive bayes classifier (from 89.2% to 94.2%)
# - **2.2% increase** in accuracy for the decision tree classifier (from 92.4% to 94.6%)
#
# For the vowel dataset:
# - **12.8% increase** in accuracy for the naive bayes classifier (from 61.3% to 74.1%)
# - **22.4% increase** in accuracy for the decision tree classifier (from 61.1% to 86.5%)
#
# **Plot the decision boundary of the boosted classifier on iris and compare it with that of the basic. What differences do you notice? Is the boundary of the boosted version more complex?**
#
# For the iris dataset, the decision boundary is more complex, however we were not able to figure out the boosted boundaries as only a few of those show up.
#
# **Can we make up for not using a more advanced model in the basic classifier (e.g. independent features) by using boosting?**
#
# Yes.

# %% [markdown]
# ## Assignment 7
# If you had to pick a classifier, naive Bayes or a decision tree or the boosted versions of these, which one would you pick?
#
# **Outliers**
#
# The naive bayes classifier without boosting is the most affected by the outliers. Decision trees (boosted and not boosted) do not seem to be affected by the outliers.
#
# **Irrelevant inputs**
#
# Decision trees are the least affected by outliers and irrelevant inputs.
#
# **Predictive power**
# The boosted classifiers are very powerful and perform better than the non-boosted classifiers, however we noticed that the boosted decision trees may suffer from overfitting.
#
# **Mixed types of data: binary, categorical or continuous features, etc**
# Naive Bayes, and its boosted version might perform better due to the continuous data.
#
# **Scalability**
#
# Decision trees perform better as we scale the dataset. Thus larger the dataset, the performance of decision trees enhances.
